# %%
import os
from dotenv import load_dotenv
from langchain_core.messages import (
    BaseMessage,
    HumanMessage,
    ToolMessage,
)
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langgraph.graph import END, StateGraph, START
load_dotenv()



def create_agent(llm, tools, system_message: str):
    """Create an agent."""
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                " You are a helpful AI assistant, collaborating with other assistants in flying a plane."
                " Use the provided tools to progress the flight."
                " Ensure to pass on the communication to the next assistant when you are done."
                " If you or any of the other assistants have the final answer or deliverable,"
                " prefix your response with FINAL ANSWER so the team knows to stop."
                " You have access to the following tools: {tool_names}.\n{system_message}",
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
    )
    prompt = prompt.partial(system_message=system_message)
    prompt = prompt.partial(tool_names=", ".join([tool.name for tool in tools]))
    return prompt | llm.bind_tools(tools)

# %%
# check key
print(os.environ.get("OPENAI_API_KEY"))

# %%
from typing import Annotated

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool


@tool
def operate_systems(action: str, system: str, value: str):
    """
    Use this to operate the aircraft systems. 
    'action' can be either 'query', 'operate', or 'report'.
    'system' can be any aircraft or ground control system.
    'value' is the value to set the system to, if applicable. if not applicable, set to 'n/a'.
    """
    return {"action":action, "system":system, "value": value}

@tool
def radio(speaker:str, listener:str, conversation:str):
    """Use this to parse any conversation between the two speakers"""
    return {"speaker":speaker, "listener":listener, "content":conversation} 
  
@tool
def render_gc_speech(gc_radio:str):
    """Use this to render the speech of the ground control radio"""
    return {"action":"radio","content":gc_radio}

@tool
def render_pilot_speech(pilot_radio:str):
    """Use this to render the speech of the pilot radio"""
    return {"action":"radio","content":pilot_radio}

@tool
def take_off():
    """Use this to run take off funtion of aircraft"""
    return {"action":"take off"}

@tool
def land():
    """Use this to run land function of aircraft"""
    return {"action":"land"}

@tool
def cruise():
    """Use this to run cruise function of aircraft"""
    return {"action":"cruise"}

@tool
def report_issue():
    """Use this to report an issue to pilot regarding any aircraft system"""
    return {"action":"report issue"}

# %%
import operator
from typing import Annotated, Sequence, TypedDict
from langchain_openai import ChatOpenAI


# This defines the object that is passed between each node
# in the graph. We will create different nodes for each agent and tool
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    sender: str
    receiver: str

# %% [markdown]
# ## Define agent nodes

# %%
import functools

from langchain_core.messages import AIMessage

# Helper function to create a node for a given agent
def agent_node(state, agent, name):
    print(f"in node:{name}")
    result = agent.invoke(state)
    # We convert the agent output into a format that is suitable to append to the global state
    if isinstance(result, ToolMessage):
        pass
    else:
        result = AIMessage(**result.dict(exclude={"type", "name"}), name=name)
    return {
        "messages": [result],
        # Since we have a strict workflow, we can
        # track the sender so we know who to pass to next.
        "sender": name,
    }


Pilot_role = """
## You're responsible for piloting the aircraft and backup communications:
- Safely operate SAR aircraft in all conditions.
- Work closely with the ground controls to follow the flight plan and respond to any adjustments in
the flight.
- Maintain communication with the Ground Station Operator as a backup.
Flies plane; backup communications - Make real-time decisions to ensure the safety of the crew and the effectiveness of the
search mission.
- Conduct the aircraft in a manner that optimizes the effectiveness of the search patterns
and strategies devised by the ground controls.
"""
GC_ROLE= """
## You're responsible for aircraft tasking tasking from ground:
- Coordinate with the pilot to ensure the safety and effectiveness of the flight.
- Task SAR aircraft based on incoming alerts and information.
- Provide pilots with weather updates and any other relevant environmental information.
Aircraft tasking from ground.
"""
llm = ChatOpenAI(model="gpt-4o")
#llm = llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")

# Research agent and node
pilot = create_agent(
    llm,
    [radio, operate_systems],
    system_message=Pilot_role,
)
pilot_node = functools.partial(agent_node, agent=pilot, name="Pilot")

# chart_generator
ground_control = create_agent(
    llm,
    [radio, operate_systems],
    system_message=GC_ROLE,
)
gc_node = functools.partial(agent_node, agent=ground_control, name="GC")

# %%
from langgraph.prebuilt import ToolNode

tools = [radio, operate_systems]
tool_node = ToolNode(tools)

# %% [markdown]
# ## Edge logic

# %%
# Either agent can decide to end
from typing import Literal


def router(state) -> Literal["call_tool", "__end__", "continue"]:
    print(f"In router")
    # This is the router
    messages = state["messages"]
    last_message = messages[-1]
    if last_message.tool_calls:
        # The previous agent is invoking a tool
        return "call_tool"
    if "FINAL ANSWER" in last_message.content:
        # Any agent decided the work is done
        return "__end__"
    return "continue"

# %% [markdown]
# ## Define graph

# %%
workflow = StateGraph(AgentState)

workflow.add_node("Pilot", pilot_node)
workflow.add_node("GC", gc_node)
workflow.add_node("call_tool", tool_node)

# the params are: 'from', 'to', 'condition'
workflow.add_conditional_edges(
    "Pilot",
    router,
    {"continue": "GC", "call_tool": "call_tool", "__end__": END},
)
workflow.add_conditional_edges(
    "GC",
    router,
    {"continue": "Pilot", "call_tool": "call_tool", "__end__": END},
)

workflow.add_conditional_edges(
    "call_tool",
    # Each agent node updates the 'sender' field
    # the tool calling node does not, meaning
    # this edge will route back to the original agent
    # who invoked the tool
    lambda x: x["sender"],
    {
        "Pilot": "Pilot",
        "GC": "GC",
    },
)
workflow.add_edge(START, "GC")
graph = workflow.compile()

# %% [markdown]
# ## Invoke

# %%
events = graph.stream(
    {
        "messages": [
            HumanMessage(
                content="Fly the plane from new york to LA"
                        "Please role play communications of these 2 agents for a takeoff sequence from dead stop at the end of the runway just before takeoff to airborne and on until landing."
                        "make each action a separate message",
            )
        ],
    },
    # Maximum number of steps to take in the graph
    {"recursion_limit": 150},
)
for s in events:
    print(s)
    print("----")
# Out:
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_L7xppliVxXgsY8L2zG2291V2', 'function': {'arguments': '{"speaker":"Ground Control","listener":"Pilot","conversation":"Pilot, this is Ground Control. You are cleared for takeoff on Runway 22L. Winds are calm, visibility is clear. Proceed when ready."}', 'name': 'radio'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 328, 'total_tokens': 381}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, name='GC', id='run-8f055add-d2f0-426a-a8bd-839ee1053d24-0', tool_calls=[{'name': 'radio', 'args': {'speaker': 'Ground Control', 'listener': 'Pilot', 'conversation': 'Pilot, this is Ground Control. You are cleared for takeoff on Runway 22L. Winds are calm, visibility is clear. Proceed when ready.'}, 'id': 'call_L7xppliVxXgsY8L2zG2291V2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 328, 'output_tokens': 53, 'total_tokens': 381})], 'sender': 'GC'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='{"speaker": "Ground Control", "listener": "Pilot", "content": "Pilot, this is Ground Control. You are cleared for takeoff on Runway 22L. Winds are calm, visibility is clear. Proceed when ready."}', name='radio', tool_call_id='call_L7xppliVxXgsY8L2zG2291V2')]}}
# ----
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_xHek8KvibaTXyn0ledP9KAgJ', 'function': {'arguments': '{"action":"operate","system":"throttle","value":"increase"}', 'name': 'operate_systems'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 440, 'total_tokens': 465}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, name='GC', id='run-b7eca400-9d11-4d08-8e64-a0e0e9fd8038-0', tool_calls=[{'name': 'operate_systems', 'args': {'action': 'operate', 'system': 'throttle', 'value': 'increase'}, 'id': 'call_xHek8KvibaTXyn0ledP9KAgJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 440, 'output_tokens': 25, 'total_tokens': 465})], 'sender': 'GC'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='{"action": "operate", "system": "throttle", "value": "increase"}', name='operate_systems', tool_call_id='call_xHek8KvibaTXyn0ledP9KAgJ')]}}
# ----
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='Pilot to Ground Control: "Ground Control, this is Pilot. Throttle increased, beginning takeoff roll."\n\nPilot to Ground Control: "Ground Control, this is Pilot. Airspeed is alive. 60 knots."\n\nPilot to Ground Control: "Ground Control, this is Pilot. V1 speed reached."\n\nPilot to Ground Control: "Ground Control, this is Pilot. Rotating."\n\nPilot to Ground Control: "Ground Control, we have positive rate of climb. Landing gear up."', additional_kwargs={'tool_calls': [{'id': 'call_vkBJWGrv2x3IpCsE6GlWZoMh', 'function': {'arguments': '{"action":"operate","system":"landing_gear","value":"up"}', 'name': 'operate_systems'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 125, 'prompt_tokens': 495, 'total_tokens': 620}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, name='GC', id='run-5c788b86-2467-43ed-8891-5a40720520ed-0', tool_calls=[{'name': 'operate_systems', 'args': {'action': 'operate', 'system': 'landing_gear', 'value': 'up'}, 'id': 'call_vkBJWGrv2x3IpCsE6GlWZoMh', 'type': 'tool_call'}], usage_metadata={'input_tokens': 495, 'output_tokens': 125, 'total_tokens': 620})], 'sender': 'GC'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='{"action": "operate", "system": "landing_gear", "value": "up"}', name='operate_systems', tool_call_id='call_vkBJWGrv2x3IpCsE6GlWZoMh')]}}
# ----
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zDUWbOjjxBPG95NXIiWeII5w', 'function': {'arguments': '{"speaker":"Pilot","listener":"Ground Control","conversation":"Ground Control, this is Pilot. We are airborne. Climbing to assigned altitude."}', 'name': 'radio'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 656, 'total_tokens': 694}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, name='GC', id='run-0c60de30-e874-4864-808f-993726cf851d-0', tool_calls=[{'name': 'radio', 'args': {'speaker': 'Pilot', 'listener': 'Ground Control', 'conversation': 'Ground Control, this is Pilot. We are airborne. Climbing to assigned altitude.'}, 'id': 'call_zDUWbOjjxBPG95NXIiWeII5w', 'type': 'tool_call'}], usage_metadata={'input_tokens': 656, 'output_tokens': 38, 'total_tokens': 694})], 'sender': 'GC'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='{"speaker": "Pilot", "listener": "Ground Control", "content": "Ground Control, this is Pilot. We are airborne. Climbing to assigned altitude."}', name='radio', tool_call_id='call_zDUWbOjjxBPG95NXIiWeII5w')]}}
# ----
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ES6BjnDGiIPdMcLnTNST0YYO', 'function': {'arguments': '{"speaker":"Ground Control","listener":"Pilot","conversation":"Pilot, this is Ground Control. Continue climb to 10,000 feet and proceed on course to Los Angeles. Contact Departure Control on frequency 123.45. Safe flight!"}', 'name': 'radio'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 738, 'total_tokens': 795}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, name='GC', id='run-13589d04-449c-4515-ad4a-785143215a96-0', tool_calls=[{'name': 'radio', 'args': {'speaker': 'Ground Control', 'listener': 'Pilot', 'conversation': 'Pilot, this is Ground Control. Continue climb to 10,000 feet and proceed on course to Los Angeles. Contact Departure Control on frequency 123.45. Safe flight!'}, 'id': 'call_ES6BjnDGiIPdMcLnTNST0YYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 738, 'output_tokens': 57, 'total_tokens': 795})], 'sender': 'GC'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='{"speaker": "Ground Control", "listener": "Pilot", "content": "Pilot, this is Ground Control. Continue climb to 10,000 feet and proceed on course to Los Angeles. Contact Departure Control on frequency 123.45. Safe flight!"}', name='radio', tool_call_id='call_ES6BjnDGiIPdMcLnTNST0YYO')]}}
# ----
# in node:GC
# In router
# {'GC': {'messages': [AIMessage(content='Pilot to Departure Control: "Departure Control, this is Pilot. We are climbing to 10,000 feet, proceeding on course to Los Angeles."\n\nDeparture Control to Pilot: "Pilot, this is Departure Control. Continue your climb to cruising altitude of 35,000 feet. Maintain current heading."\n\nPilot to Departure Control: "Roger, Departure Control. Climbing to 35,000 feet. Maintaining current heading."\n\n(After some time)\n\nPilot to Center Control: "Center Control, this is Pilot. We are at cruising altitude of 35,000 feet en route to Los Angeles."\n\nCenter Control to Pilot: "Roger, Pilot. Maintain cruising altitude and proceed on course. Report any changes."\n\nPilot to Center Control: "Wilco, Center Control."\n\n(Approaching Los Angeles)\n\nPilot to Approach Control: "Approach Control, this is Pilot. We are descending to 10,000 feet, preparing for approach to Los Angeles."\n\nApproach Control to Pilot: "Roger, Pilot. Descend to 5,000 feet and prepare for ILS approach to Runway 25L."\n\nPilot to Approach Control: "Roger, Approach Control. Descending to 5,000 feet for ILS approach to Runway 25L."\n\n(After some time)\n\nPilot to Tower: "Tower, this is Pilot. We are on final approach to Runway 25L."\n\nTower to Pilot: "Roger, Pilot. You are cleared to land on Runway 25L. Wind is 5 knots from the west."\n\nPilot to Tower: "Cleared to land on Runway 25L. Thank you, Tower."\n\n(After landing)\n\nPilot to Ground Control: "Ground Control, this is Pilot. We have landed and are taxiing to the gate."\n\nGround Control to Pilot: "Roger, Pilot. Taxi to Gate 12 via Taxiway Alpha. Welcome to Los Angeles."\n\nPilot to Ground Control: "Taxiing to Gate 12 via Taxiway Alpha. Thank you, Ground Control." \n\nFINAL ANSWER', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 412, 'prompt_tokens': 858, 'total_tokens': 1270}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, name='GC', id='run-766b4325-70d0-4205-939c-1483fd75ff6c-0', usage_metadata={'input_tokens': 858, 'output_tokens': 412, 'total_tokens': 1270})], 'sender': 'GC'}}
# ----

# %%
import os
import anthropic
from dotenv import load_dotenv
load_dotenv()

client = anthropic.Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
)

print(os.environ.get("ANTHROPIC_API_KEY"))

message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Hello, Claude"}
    ]
)
print(message.content)
